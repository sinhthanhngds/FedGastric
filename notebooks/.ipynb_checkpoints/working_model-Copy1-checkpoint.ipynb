# %%
import boto3
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
from PIL import Image
import numpy as np
import io
import os

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
from torchvision import models

# %%
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, TensorDataset

# %%
# !pwd
# Out:
# /kaggle/working

# %%
!

# %% [markdown]
# ### Setting up AWS client

# %%
def aws_client():
    ## read user keys 
    keys = pd.read_csv ('/kaggle/input/access-key/team_user_accessKeys.csv')
    
    # id and keys 
    aws_access_key_id = keys['Access key ID'].values[0]
    aws_secret_access_key = keys['Secret access key'].values[0]

    # access the aws S3 client and return it
    s3_client = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

    return s3_client

# %%
aws_client()

# %%
s3_client = aws_client()

# %%
s3_client.list_buckets()['Buckets']
# Out:
# [{'Name': 'gashissdb-dataset',
#   'CreationDate': datetime.datetime(2024, 8, 28, 10, 26, 59, tzinfo=tzlocal())},
#  {'Name': 'gastric-cancer-data',
#   'CreationDate': datetime.datetime(2024, 8, 14, 7, 57, 37, tzinfo=tzlocal())},
#  {'Name': 'gastric-data-zip',
#   'CreationDate': datetime.datetime(2024, 8, 16, 7, 35, 42, tzinfo=tzlocal())}]

# %% [markdown]
# ### Downloading images from AWS bucket

# %%
class Data:
    def __init__ (self, image_size, label, num_instances):
        self.bucket_name = 'gashissdb-dataset'
        self.image_size = image_size
        self.label = label
        self.keys = []
        self.data = []
        self.target = None
        self.get_data(num_instances)
        self.download_images()
        
    
    def get_data (self, num_instances = 30):
        paginator = s3_client.get_paginator('list_objects_v2')
        pages = paginator.paginate (Bucket = self.bucket_name, Prefix = f'{self.image_size}/{self.label}')
        count = 0
        for page in pages:
            if 'Contents' in page:
                for obj in page['Contents']:
                    self.keys.append (obj['Key'])
                    count+=1 
                    if count > num_instances:
                        return
                    
    def download_images (self, target_size = (224, 224)):
        for key in self.keys:
            s3_object = s3_client.get_object (Bucket = self.bucket_name, Key = key)
            image_data = s3_object['Body'].read()
            image = Image.open (io.BytesIO(image_data)).convert('RGB')
            image = image.resize (target_size)
            image_array = np.array (image)[:, :, :-1]
            # Add the third color channel, the 1st channel was taken
            image_array = np.dstack((image_array, image_array[:, :, 0])) 
            self.data.append (image_array)
        
        self.data = np.array (self.data)
        
        if self.label == 'Normal':
            self.target = np.zeros (self.data.shape[0]).astype ('int')
        else:
            self.target = np.ones (self.data.shape[0]).astype ('int')

# %%
image_size = 120
number_of_normal_instances = 500
number_of_abnormal_instances = 500
abnormal = Data (image_size, 'Abnormal', number_of_abnormal_instances)
normal = Data (image_size, 'Normal', number_of_normal_instances)

# %%
sample = abnormal.data[0]

# %%
fig, ax = plt.subplots (4, 4, figsize = (15, 15))
k = 0
for i in range (4):
    for j in range (4):
        ax[i, j].imshow (normal.data[k])
        k+=1

# %%
fig, ax = plt.subplots (4, 4, figsize = (15, 15))
k = 0
for i in range (4):
    for j in range (4):
        ax[i, j].imshow (abnormal.data[k])
        k+=1

# %%
X = np.concatenate ([normal.data, abnormal.data])
y = np.concatenate ([normal.target, abnormal.target])

# %%
#split dataset to 4 clinics
num_parts = 4
indices = np.arange(len(X))
np.random.shuffle(indices)

# Shuffle images and labels based on the shuffled indices, keeping the alignment
shuffled_images = X[indices]
shuffled_labels = y[indices]

# Calculate the size of each part
part_size = len(shuffled_images) // num_parts

# Split the shuffled images and labels into 4 equal parts
image_splits = np.array_split(shuffled_images, num_parts)
label_splits = np.array_split(shuffled_labels, num_parts)

# %%
X.shape
# Out:
# (1002, 224, 224, 3)

# %%
clinics = {
    'clinic_0' : {
        'X': image_splits[0],
        'y': label_splits[0]
    },
    'clinic_1' : {
        'X': image_splits[1],
        'y': label_splits[1]
    },
    'clinic_2' : {
        'X': image_splits[2],
        'y': label_splits[2]
    },
    'clinic_3' : {
        'X': image_splits[3],
        'y': label_splits[3],
    }
}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Data Preprocessing (Data Loader setup for Torch model)

# %%
def preprocessing (images):
    norm = images/255
    imagenet_mean = np.array([0.485, 0.456, 0.406])
    imagenet_std = np.array([0.229, 0.224, 0.225])
    output = (norm - imagenet_mean)/imagenet_std
    return output

'''
def preprocessing (images):
    norm = images/255
    imagenet_mean = np.array([0.485, 0.456])
    imagenet_std = np.array([0.229, 0.224])
    output = (norm - imagenet_mean)/imagenet_std
    return output'''
# Out:
# '\ndef preprocessing (images):\n    norm = images/255\n    imagenet_mean = np.array([0.485, 0.456])\n    imagenet_std = np.array([0.229, 0.224])\n    output = (norm - imagenet_mean)/imagenet_std\n    return output'

# %%
def dataloader (clinic):
    batch_size = 32
    images = clinics[clinic]['X']
    images = preprocessing (images)
    labels = clinics[clinic]['y']
    
    tensorX = torch.tensor (images, dtype = torch.float32, device = device).permute (0, 3, 2, 1)
    tensory = torch.tensor (labels, dtype = torch.float, device = device).unsqueeze(1)
    
    #dataset = TensorDataset (tensorX, tensory)
    
    X_train, X_test, y_train, y_test = train_test_split (tensorX, tensory, test_size = 0.2, random_state = 42)
    X_train, X_val, y_train, y_val = train_test_split (X_train, y_train, test_size = 0.2, random_state = 42)
    
    train_dataset = TensorDataset (X_train, y_train)
    val_dataset = TensorDataset (X_val, y_val)
    test_dataset = TensorDataset (X_test, y_test)
    
    train_loader = DataLoader (train_dataset, batch_size = 32, shuffle = True)
    val_loader = DataLoader (val_dataset, batch_size = 32, shuffle = False)
    test_loader = DataLoader (test_dataset, batch_size = 32, shuffle = False)
    
    return train_loader, val_loader, test_loader

# %% [markdown]
# ### Client model

# %%
def resnet18 (weight = None):
    resnet18 = models.resnet18 (weights = weight).to(device)
    resnet18.fc = nn.Sequential(
    nn.Linear(in_features = 512, out_features = 256, bias = True),
    nn.Dropout(p = 0.5),
    nn.Linear(in_features = 256, out_features = 1, bias = True),
    #nn.Sigmoid ()
)
    
    return resnet18

# %%
def vgg19 (weight=None):
    vgg19 = models.vgg19 (weights=weight).to(device)
    
    for param in vgg19.parameters():
        param.requires_grad = False
        
    vgg19.classifier = nn.Sequential(
        nn.Linear(25088, 4096),        
        nn.ReLU(inplace=True),
        nn.Dropout(p=0.5),
        nn.Linear(4096, 4096),       
        nn.ReLU(inplace=True),
        nn.Dropout(p=0.5),
        nn.Linear(4096, 2)            
    )
    for param in vgg19.classifier.parameters():
        param.requires_grad = True
    
    return vgg19

# %%
def efficientnet(weight = None):
    efficientnet = models.efficientnet_v2_s(weights = weight)
    efficientnet.classifier[1] = nn.Linear (1280, 1, bias = True)
    
    return efficientnet

# %%
def resnet50 (weight = None):
    resnet50 = models.resnet50(weights = weight)
    resnet50.fc = nn.Sequential(
        nn.Linear (in_features=2048, out_features = 1000, bias = True),
        nn.Linear (in_features=1000, out_features = 500, bias= True),
        nn.Linear (in_features = 500, out_features = 1, bias = True),
        nn.ReLU(inplace = True)
    )
    return resnet50

# %%
import torch
import torch.optim as optim

# Custom threshold for binary classification
threshold = 0.5

# Calculate accuracy using a custom threshold
def calculate_accuracy(outputs, labels, threshold=0):
    preds = (outputs > threshold).float()  # Apply threshold to get binary predictions (0 or 1)
    correct = (preds == labels).float().sum()  # Count the number of correct predictions
    accuracy = correct / labels.size(0)  # Get the accuracy
    return accuracy

def train_local_model(model, train_loader, val_loader, num_epochs=10):
    # Binary Cross Entropy Loss with logits (applies Sigmoid inside the loss function)
    criterion = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor([10], device=device))  
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_loss = 0.0
        running_accuracy = 0.0
        total_train = 0

        for images, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(images)
            
            # Calculate loss
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_accuracy += calculate_accuracy(outputs, labels, threshold)
            total_train += 1  # Count batches

        epoch_loss = running_loss / total_train
        epoch_accuracy = running_accuracy / total_train
        
        print(f"Epoch {epoch + 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}")

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_accuracy = 0.0
        total_val = 0

        with torch.no_grad():
            for images, labels in val_loader:
                outputs = model(images)
                
                # Calculate validation loss
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                
                # Calculate accuracy with the custom threshold
                val_accuracy += calculate_accuracy(outputs, labels, threshold)
                total_val += 1  # Count batches

        avg_val_loss = val_loss / total_val
        avg_val_accuracy = val_accuracy / total_val
        
        print(f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {avg_val_accuracy:.4f}")
        
    return model.state_dict()

# %% [markdown]
# ### Federated Learning

# %%
def federated_averaging (client_weights):
    avg_weights = client_weights[0].copy()
    
    for key in avg_weights.keys():
        for key in avg_weights.keys():
            for i in range (1, len (client_weights)):
                avg_weights[key] += client_weights[i][key]
                
            avg_weights[key] = avg_weights[key] / len (client_weights)
            
    return avg_weights

# %%
def federated_learning (num_clients, num_rounds, train_loaders, val_loaders):
    global_model = resnet18('DEFAULT')
    global_weights = global_model.state_dict()
    
    for round_num in range (num_rounds):
        print (f'Round {round_num+1}')
        
        client_weights = []
        
        for client_id in range (num_clients):
            print (f'client {client_id+1} training...')
            
            local_model = resnet18()
            local_model.load_state_dict (global_weights)
            local_model.to(device)
            
            client_train_loader = train_loaders[client_id]
            client_val_loader = val_loaders[client_id]
            client_updated_weights = train_local_model (local_model, client_train_loader, client_val_loader)
            
            client_weights.append (client_updated_weights)
            
        global_weights = federated_averaging (client_weights)
        
        global_model.load_state_dict (global_weights)
        
    return global_model

# %%
num_clients = 4

num_rounds = 3

train_loader_0, val_loader_0, test_loader_0 = dataloader ('clinic_0')

train_loader_1, val_loader_1, test_loader_1 = dataloader ('clinic_1')

train_loader_2, val_loader_2, test_loader_2 = dataloader ('clinic_2')

train_loader_3, val_loader_3, test_loader_3 = dataloader ('clinic_3')


train_loaders = [train_loader_0, train_loader_1, train_loader_2, train_loader_3]
val_loaders = [val_loader_0, val_loader_1, val_loader_2, val_loader_3]

global_model = federated_learning (num_clients, num_rounds, train_loaders, val_loaders)
# Out:
# Round 1
# client 1 training...
# Epoch 1, Loss: 4.2892, Accuracy: 0.5000
# Validation Loss: 3.0120, Validation Accuracy: 0.6406
# Epoch 2, Loss: 1.1961, Accuracy: 0.7375
# Validation Loss: 1.6357, Validation Accuracy: 0.6875
# Epoch 3, Loss: 0.8455, Accuracy: 0.6875
# Validation Loss: 1.3034, Validation Accuracy: 0.7188
# Epoch 4, Loss: 0.6894, Accuracy: 0.7375
# Validation Loss: 1.1939, Validation Accuracy: 0.7656
# Epoch 5, Loss: 0.5280, Accuracy: 0.7688
# Validation Loss: 1.1630, Validation Accuracy: 0.7969
# Epoch 6, Loss: 0.3959, Accuracy: 0.8625
# Validation Loss: 1.1825, Validation Accuracy: 0.8281
# Epoch 7, Loss: 0.2415, Accuracy: 0.9625
# Validation Loss: 1.1414, Validation Accuracy: 0.8281
# Epoch 8, Loss: 0.1765, Accuracy: 1.0000
# Validation Loss: 1.1253, Validation Accuracy: 0.8281
# Epoch 9, Loss: 0.1334, Accuracy: 1.0000
# Validation Loss: 1.1629, Validation Accuracy: 0.8438
# Epoch 10, Loss: 0.0889, Accuracy: 1.0000
# Validation Loss: 1.1786, Validation Accuracy: 0.8438
# client 2 training...
# Epoch 1, Loss: 3.5117, Accuracy: 0.6062
# Validation Loss: 2.5244, Validation Accuracy: 0.6719
# Epoch 2, Loss: 1.0985, Accuracy: 0.6625
# Validation Loss: 1.6729, Validation Accuracy: 0.7188
# Epoch 3, Loss: 0.9734, Accuracy: 0.6062
# Validation Loss: 1.2833, Validation Accuracy: 0.7188
# Epoch 4, Loss: 0.6530, Accuracy: 0.7188
# Validation Loss: 1.1208, Validation Accuracy: 0.7500
# Epoch 5, Loss: 0.4097, Accuracy: 0.8813
# Validation Loss: 1.0537, Validation Accuracy: 0.7500
# Epoch 6, Loss: 0.2689, Accuracy: 0.9688
# Validation Loss: 1.0448, Validation Accuracy: 0.7969
# Epoch 7, Loss: 0.1533, Accuracy: 1.0000
# Validation Loss: 1.0240, Validation Accuracy: 0.8906
# Epoch 8, Loss: 0.1220, Accuracy: 0.9938
# Validation Loss: 0.9311, Validation Accuracy: 0.8594
# Epoch 9, Loss: 0.0854, Accuracy: 1.0000
# Validation Loss: 0.8746, Validation Accuracy: 0.8594
# Epoch 10, Loss: 0.0811, Accuracy: 1.0000
# Validation Loss: 0.8730, Validation Accuracy: 0.8750
# client 3 training...
# Epoch 1, Loss: 3.6843, Accuracy: 0.5500
# Validation Loss: 2.4872, Validation Accuracy: 0.6562
# Epoch 2, Loss: 1.1273, Accuracy: 0.6875
# Validation Loss: 1.7117, Validation Accuracy: 0.6562
# Epoch 3, Loss: 0.8235, Accuracy: 0.6500
# Validation Loss: 1.4000, Validation Accuracy: 0.6562
# Epoch 4, Loss: 0.6352, Accuracy: 0.7250
# Validation Loss: 1.2214, Validation Accuracy: 0.6562
# Epoch 5, Loss: 0.4597, Accuracy: 0.8000
# Validation Loss: 1.0661, Validation Accuracy: 0.6562
# Epoch 6, Loss: 0.2728, Accuracy: 0.9375
# Validation Loss: 0.9885, Validation Accuracy: 0.7188
# Epoch 7, Loss: 0.1691, Accuracy: 0.9875
# Validation Loss: 0.9741, Validation Accuracy: 0.7188
# Epoch 8, Loss: 0.1244, Accuracy: 1.0000
# Validation Loss: 0.9501, Validation Accuracy: 0.7812
# Epoch 9, Loss: 0.0826, Accuracy: 1.0000
# Validation Loss: 0.9401, Validation Accuracy: 0.7969
# Epoch 10, Loss: 0.0578, Accuracy: 1.0000
# Validation Loss: 0.9254, Validation Accuracy: 0.7812
# client 4 training...
# Epoch 1, Loss: 3.8828, Accuracy: 0.5563
# Validation Loss: 2.8320, Validation Accuracy: 0.6875
# Epoch 2, Loss: 1.1852, Accuracy: 0.7063
# Validation Loss: 1.7861, Validation Accuracy: 0.6719
# Epoch 3, Loss: 0.8649, Accuracy: 0.6562
# Validation Loss: 1.4760, Validation Accuracy: 0.6562
# Epoch 4, Loss: 0.7512, Accuracy: 0.6938
# Validation Loss: 1.3485, Validation Accuracy: 0.7188
# Epoch 5, Loss: 0.5294, Accuracy: 0.7625
# Validation Loss: 1.2732, Validation Accuracy: 0.7500
# Epoch 6, Loss: 0.3695, Accuracy: 0.8750
# Validation Loss: 1.2460, Validation Accuracy: 0.7500
# Epoch 7, Loss: 0.2381, Accuracy: 0.9688
# Validation Loss: 1.2732, Validation Accuracy: 0.7812
# Epoch 8, Loss: 0.1394, Accuracy: 0.9938
# Validation Loss: 1.3268, Validation Accuracy: 0.7812
# Epoch 9, Loss: 0.1014, Accuracy: 1.0000
# Validation Loss: 1.4685, Validation Accuracy: 0.7812
# Epoch 10, Loss: 0.0893, Accuracy: 1.0000
# Validation Loss: 1.5755, Validation Accuracy: 0.7969
# Round 2
# client 1 training...
# Epoch 1, Loss: 1.0236, Accuracy: 0.8188
# Validation Loss: 1.5346, Validation Accuracy: 0.7969
# Epoch 2, Loss: 0.4784, Accuracy: 0.8125
# Validation Loss: 1.3353, Validation Accuracy: 0.8125
# Epoch 3, Loss: 0.2495, Accuracy: 0.9250
# Validation Loss: 1.6493, Validation Accuracy: 0.8125
# Epoch 4, Loss: 0.1117, Accuracy: 1.0000
# Validation Loss: 2.2736, Validation Accuracy: 0.7188
# Epoch 5, Loss: 0.0652, Accuracy: 1.0000
# Validation Loss: 2.6419, Validation Accuracy: 0.7812
# Epoch 6, Loss: 0.0399, Accuracy: 1.0000
# Validation Loss: 2.5348, Validation Accuracy: 0.7812
# Epoch 7, Loss: 0.0197, Accuracy: 1.0000
# Validation Loss: 2.3129, Validation Accuracy: 0.8125
# Epoch 8, Loss: 0.0191, Accuracy: 1.0000
# Validation Loss: 2.1662, Validation Accuracy: 0.8125
# Epoch 9, Loss: 0.0165, Accuracy: 1.0000
# Validation Loss: 2.0613, Validation Accuracy: 0.8125
# Epoch 10, Loss: 0.0087, Accuracy: 1.0000
# Validation Loss: 1.9756, Validation Accuracy: 0.8125
# client 2 training...
# Epoch 1, Loss: 0.3444, Accuracy: 0.9563
# Validation Loss: 2.0849, Validation Accuracy: 0.7188
# Epoch 2, Loss: 0.1480, Accuracy: 0.9812
# Validation Loss: 1.1736, Validation Accuracy: 0.8750
# Epoch 3, Loss: 0.1116, Accuracy: 1.0000
# Validation Loss: 1.0391, Validation Accuracy: 0.7969
# Epoch 4, Loss: 0.1854, Accuracy: 0.9375
# Validation Loss: 2.3032, Validation Accuracy: 0.8281
# Epoch 5, Loss: 0.0316, Accuracy: 1.0000
# Validation Loss: 3.4761, Validation Accuracy: 0.8125
# Epoch 6, Loss: 0.0279, Accuracy: 1.0000
# Validation Loss: 1.8395, Validation Accuracy: 0.8438
# Epoch 7, Loss: 0.0275, Accuracy: 1.0000
# Validation Loss: 0.7346, Validation Accuracy: 0.8594
# Epoch 8, Loss: 0.0097, Accuracy: 1.0000
# Validation Loss: 0.6355, Validation Accuracy: 0.8281
# Epoch 9, Loss: 0.0179, Accuracy: 1.0000
# Validation Loss: 0.6955, Validation Accuracy: 0.7969
# Epoch 10, Loss: 0.0063, Accuracy: 1.0000
# Validation Loss: 0.6966, Validation Accuracy: 0.7969
# client 3 training...
# Epoch 1, Loss: 0.3628, Accuracy: 0.9563
# Validation Loss: 0.9402, Validation Accuracy: 0.8594
# Epoch 2, Loss: 0.1428, Accuracy: 1.0000
# Validation Loss: 1.1199, Validation Accuracy: 0.8750
# Epoch 3, Loss: 0.0725, Accuracy: 1.0000
# Validation Loss: 1.1384, Validation Accuracy: 0.8281
# Epoch 4, Loss: 0.0710, Accuracy: 1.0000
# Validation Loss: 1.0717, Validation Accuracy: 0.9375
# Epoch 5, Loss: 0.0194, Accuracy: 1.0000
# Validation Loss: 0.9652, Validation Accuracy: 0.9531
# Epoch 6, Loss: 0.0102, Accuracy: 1.0000
# Validation Loss: 0.8212, Validation Accuracy: 0.9531
# Epoch 7, Loss: 0.0145, Accuracy: 1.0000
# Validation Loss: 0.6418, Validation Accuracy: 0.9531
# Epoch 8, Loss: 0.0053, Accuracy: 1.0000
# Validation Loss: 0.6077, Validation Accuracy: 0.9219
# Epoch 9, Loss: 0.0043, Accuracy: 1.0000
# Validation Loss: 0.6166, Validation Accuracy: 0.9219
# Epoch 10, Loss: 0.0035, Accuracy: 1.0000
# Validation Loss: 0.6335, Validation Accuracy: 0.9219
# client 4 training...
# Epoch 1, Loss: 0.6469, Accuracy: 0.8562
# Validation Loss: 1.3130, Validation Accuracy: 0.8281
# Epoch 2, Loss: 0.3086, Accuracy: 0.9125
# Validation Loss: 1.1967, Validation Accuracy: 0.8281
# Epoch 3, Loss: 0.1444, Accuracy: 0.9875
# Validation Loss: 1.1750, Validation Accuracy: 0.8594
# Epoch 4, Loss: 0.0587, Accuracy: 1.0000
# Validation Loss: 2.0782, Validation Accuracy: 0.8125
# Epoch 5, Loss: 0.0604, Accuracy: 1.0000
# Validation Loss: 2.8283, Validation Accuracy: 0.8125
# Epoch 6, Loss: 0.0231, Accuracy: 1.0000
# Validation Loss: 3.0431, Validation Accuracy: 0.8438
# Epoch 7, Loss: 0.0165, Accuracy: 1.0000
# Validation Loss: 3.0575, Validation Accuracy: 0.8438
# Epoch 8, Loss: 0.0076, Accuracy: 1.0000
# Validation Loss: 2.9518, Validation Accuracy: 0.8438
# Epoch 9, Loss: 0.0052, Accuracy: 1.0000
# Validation Loss: 2.8928, Validation Accuracy: 0.8438
# Epoch 10, Loss: 0.0063, Accuracy: 1.0000
# Validation Loss: 2.9590, Validation Accuracy: 0.8438
# Round 3
# client 1 training...
# Epoch 1, Loss: 1.4690, Accuracy: 0.8250
# Validation Loss: 2.0418, Validation Accuracy: 0.7812
# Epoch 2, Loss: 0.4404, Accuracy: 0.8688
# Validation Loss: 3.0419, Validation Accuracy: 0.8594
# Epoch 3, Loss: 0.2056, Accuracy: 0.9375
# Validation Loss: 2.6871, Validation Accuracy: 0.8750
# Epoch 4, Loss: 0.0864, Accuracy: 0.9938
# Validation Loss: 2.0302, Validation Accuracy: 0.8750
# Epoch 5, Loss: 0.0590, Accuracy: 1.0000
# Validation Loss: 1.6582, Validation Accuracy: 0.8750
# Epoch 6, Loss: 0.0354, Accuracy: 1.0000
# Validation Loss: 1.6092, Validation Accuracy: 0.8281
# Epoch 7, Loss: 0.0367, Accuracy: 1.0000
# Validation Loss: 1.6788, Validation Accuracy: 0.8281
# Epoch 8, Loss: 0.0140, Accuracy: 1.0000
# Validation Loss: 1.7365, Validation Accuracy: 0.8281
# Epoch 9, Loss: 0.0127, Accuracy: 1.0000
# Validation Loss: 1.7987, Validation Accuracy: 0.8281
# Epoch 10, Loss: 0.0181, Accuracy: 1.0000
# Validation Loss: 1.8412, Validation Accuracy: 0.8281
# client 2 training...
# Epoch 1, Loss: 0.0214, Accuracy: 1.0000
# Validation Loss: 0.6463, Validation Accuracy: 0.8750
# Epoch 2, Loss: 0.0053, Accuracy: 1.0000
# Validation Loss: 1.0547, Validation Accuracy: 0.7812
# Epoch 3, Loss: 0.0047, Accuracy: 1.0000
# Validation Loss: 1.0021, Validation Accuracy: 0.8125
# Epoch 4, Loss: 0.0020, Accuracy: 1.0000
# Validation Loss: 1.3814, Validation Accuracy: 0.8125
# Epoch 5, Loss: 0.0014, Accuracy: 1.0000
# Validation Loss: 1.8975, Validation Accuracy: 0.8125
# Epoch 6, Loss: 0.0012, Accuracy: 1.0000
# Validation Loss: 1.5542, Validation Accuracy: 0.8125
# Epoch 7, Loss: 0.0003, Accuracy: 1.0000
# Validation Loss: 0.9722, Validation Accuracy: 0.8438
# Epoch 8, Loss: 0.0005, Accuracy: 1.0000
# Validation Loss: 0.7335, Validation Accuracy: 0.9062
# Epoch 9, Loss: 0.0002, Accuracy: 1.0000
# Validation Loss: 0.6313, Validation Accuracy: 0.9062
# Epoch 10, Loss: 0.0003, Accuracy: 1.0000
# Validation Loss: 0.5997, Validation Accuracy: 0.9062
# client 3 training...
# Epoch 1, Loss: 0.0729, Accuracy: 0.9938
# Validation Loss: 1.9639, Validation Accuracy: 0.9062
# Epoch 2, Loss: 0.0317, Accuracy: 1.0000
# Validation Loss: 4.0816, Validation Accuracy: 0.8125
# Epoch 3, Loss: 0.0145, Accuracy: 1.0000
# Validation Loss: 4.1254, Validation Accuracy: 0.7344
# Epoch 4, Loss: 0.0197, Accuracy: 1.0000
# Validation Loss: 2.5485, Validation Accuracy: 0.8438
# Epoch 5, Loss: 0.0037, Accuracy: 1.0000
# Validation Loss: 1.7504, Validation Accuracy: 0.8750
# Epoch 6, Loss: 0.0139, Accuracy: 1.0000
# Validation Loss: 1.6136, Validation Accuracy: 0.7188
# Epoch 7, Loss: 0.0037, Accuracy: 1.0000
# Validation Loss: 1.6629, Validation Accuracy: 0.7188
# Epoch 8, Loss: 0.0047, Accuracy: 1.0000
# Validation Loss: 1.7168, Validation Accuracy: 0.7188
# Epoch 9, Loss: 0.0010, Accuracy: 1.0000
# Validation Loss: 1.7124, Validation Accuracy: 0.7188
# Epoch 10, Loss: 0.0010, Accuracy: 1.0000
# Validation Loss: 1.6887, Validation Accuracy: 0.7031
# client 4 training...
# Epoch 1, Loss: 0.0332, Accuracy: 0.9938
# Validation Loss: 2.2865, Validation Accuracy: 0.7969
# Epoch 2, Loss: 0.0281, Accuracy: 1.0000
# Validation Loss: 2.0430, Validation Accuracy: 0.7969
# Epoch 3, Loss: 0.0053, Accuracy: 1.0000
# Validation Loss: 2.9967, Validation Accuracy: 0.8438
# Epoch 4, Loss: 0.0114, Accuracy: 1.0000
# Validation Loss: 4.1759, Validation Accuracy: 0.8281
# Epoch 5, Loss: 0.0034, Accuracy: 1.0000
# Validation Loss: 4.8591, Validation Accuracy: 0.8438
# Epoch 6, Loss: 0.0052, Accuracy: 1.0000
# Validation Loss: 4.5950, Validation Accuracy: 0.8281
# Epoch 7, Loss: 0.0018, Accuracy: 1.0000
# Validation Loss: 3.8935, Validation Accuracy: 0.8281
# Epoch 8, Loss: 0.0022, Accuracy: 1.0000
# Validation Loss: 3.4118, Validation Accuracy: 0.8750
# Epoch 9, Loss: 0.0021, Accuracy: 1.0000
# Validation Loss: 3.4679, Validation Accuracy: 0.8750
# Epoch 10, Loss: 0.0005, Accuracy: 1.0000
# Validation Loss: 3.7603, Validation Accuracy: 0.8594
